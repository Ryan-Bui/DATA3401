# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('Galaxy_Data_-_All_Galaxies.csv')

# %%
df
# Out:
#               OBJID          RA        DEC  \
# 0      5.880180e+17  218.580808   8.161055
# 1      5.877300e+17  239.931122   3.644782
# 2      5.877242e+17   10.641342  15.445178
# 3      5.877415e+17  165.379954  28.187846
# 4      5.877300e+17  216.307612  -1.099459
# ...             ...         ...        ...
# 19995  5.877334e+17  231.967240  50.455685
# 19996  5.880177e+17  243.777330   6.092806
# 19997  5.877250e+17  184.644965  -1.598657
# 19998  5.877258e+17  118.714675  45.705057
# 19999  5.880177e+17  173.612528  12.493277
#
#                                                  IMG_URL  REDSHIFT  \
# 0      http://skyserver.sdss.org/dr12/en/tools/explor...  0.053766
# 1      http://skyserver.sdss.org/dr12/en/tools/explor...  0.054367
# 2      http://skyserver.sdss.org/dr12/en/tools/explor...  0.079503
# 3      http://skyserver.sdss.org/dr12/en/tools/explor...  0.069913
# 4      http://skyserver.sdss.org/dr12/en/tools/explor...  0.055574
# ...

# %%
mass = np.array(df['LOG_MASS'])

# %%
mass
# Out:
# array([10.51641178, 10.59243011, 10.82852364, ..., 10.00266552,
#        10.98664761, 10.66286278])

# %%
m = 10**mass

# %%
mass_df = pd.DataFrame(m)

# %%
mass_df
# Out:
#                   0
# 0      3.284065e+10
# 1      3.912282e+10
# 2      6.737886e+10
# 3      4.706355e+10
# 4      9.221140e+09
# ...             ...
# 19995  1.255547e+11
# 19996  2.320999e+11
# 19997  1.006156e+10
# 19998  9.697228e+10
# 19999  4.601112e+10
#
# [20000 rows x 1 columns]

# %%
mass_df.to_csv("mass.csv", index = False)

# %%
df1 = pd.read_csv('Spirals.csv')

# %%
df1
# Out:
#              OBJID          RA        DEC  \
# 0     5.877300e+17  239.931122   3.644782
# 1     5.880180e+17  199.705642  39.656256
# 2     5.877336e+17  252.147662  35.160900
# 3     5.877325e+17  126.812745  31.878147
# 4     5.880180e+17  237.891611  27.370528
# ...            ...         ...        ...
# 6876  5.877319e+17  176.727306  55.395927
# 6877  5.877381e+17  121.589235  53.069495
# 6878  5.877258e+17  224.903804  63.024535
# 6879  5.877378e+17  123.219860  51.834880
# 6880  5.877366e+17  246.281627  24.261226
#
#                                                 IMG_URL  REDSHIFT  \
# 0     http://skyserver.sdss.org/dr12/en/tools/explor...  0.054367
# 1     http://skyserver.sdss.org/dr12/en/tools/explor...  0.073667
# 2     http://skyserver.sdss.org/dr12/en/tools/explor...  0.081899
# 3     http://skyserver.sdss.org/dr12/en/tools/explor...  0.050641
# 4     http://skyserver.sdss.org/dr12/en/tools/explor...  0.075346
# ...

# %%
mass1 = np.array(df1['LOG_MASS'])

# %%
mass1
# Out:
# array([10.59243011,  9.99163151,  9.81799889, ..., 10.43617439,
#        10.39936543, 10.14676476])

# %%
m1 = 10**mass1

# %%
m1
# Out:
# array([3.91228163e+10, 9.80915303e+09, 6.57656156e+09, ...,
#        2.73007382e+10, 2.50821887e+10, 1.40205406e+10])

# %%
mass1_df = pd.DataFrame(m1)

# %%
mass1_df
# Out:
#                  0
# 0     3.912282e+10
# 1     9.809153e+09
# 2     6.576562e+09
# 3     6.046070e+09
# 4     4.601678e+10
# ...            ...
# 6876  2.107024e+10
# 6877  2.752207e+10
# 6878  2.730074e+10
# 6879  2.508219e+10
# 6880  1.402054e+10
#
# [6881 rows x 1 columns]

# %%
mass1_df.to_csv("spiral_mass.csv", index = False)

# %%
df2 = pd.read_csv('Ellipticals.csv')
df2
# Out:
#              OBJID          RA        DEC  \
# 0     5.877269e+17  337.154074  -9.767217
# 1     5.877294e+17  127.522598  43.759190
# 2     5.880155e+17   16.453773  -1.149316
# 3     5.877315e+17   46.979240  -0.946646
# 4     5.877417e+17  150.082461  22.037433
# ...            ...         ...        ...
# 2504  5.877394e+17  134.348028  24.237455
# 2505  5.880180e+17  219.314108   7.755419
# 2506  5.877334e+17  231.967240  50.455685
# 2507  5.877258e+17  118.714675  45.705057
# 2508  5.880177e+17  173.612528  12.493277
#
#                                                 IMG_URL  REDSHIFT  \
# 0     http://skyserver.sdss.org/dr12/en/tools/explor...  0.054510
# 1     http://skyserver.sdss.org/dr12/en/tools/explor...  0.083467
# 2     http://skyserver.sdss.org/dr12/en/tools/explor...  0.064887
# 3     http://skyserver.sdss.org/dr12/en/tools/explor...  0.066651
# 4     http://skyserver.sdss.org/dr12/en/tools/explor...  0.082611
# ...

# %%
mass2 = np.array(df2['LOG_MASS'])
mass2
# Out:
# array([10.55156136, 11.03006935, 10.89962959, ..., 11.09883308,
#        10.98664761, 10.66286278])

# %%
m2 = 10**mass2

# %%
m2
# Out:
# array([3.56091297e+10, 1.07169042e+11, 7.93651041e+10, ...,
#        1.25554730e+11, 9.69722807e+10, 4.60111174e+10])

# %%
mass2_df = pd.DataFrame(m2)

# %%
mass2_df
# Out:
#                  0
# 0     3.560913e+10
# 1     1.071690e+11
# 2     7.936510e+10
# 3     4.268364e+10
# 4     8.181236e+10
# ...            ...
# 2504  4.516414e+10
# 2505  3.048003e+10
# 2506  1.255547e+11
# 2507  9.697228e+10
# 2508  4.601112e+10
#
# [2509 rows x 1 columns]

# %%
mass2_df.to_csv("elliptical_mass.csv", index = False)
